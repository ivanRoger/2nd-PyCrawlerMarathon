# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11775179450","type":"PushEvent","actor":{"id":61994807,"login":"lisa5701","display_login":"lisa5701","gravatar_id":"","url":"https://api.github.com/users/lisa5701","avatar_url":"https://avatars.githubusercontent.com/u/61994807?"},"repo":{"id":246156410,"name":"lisa5701/-Wanna-Fu-ck-Me-Very-Hungry-My-Pus-sy-Meet-face2face--amp--Fu-ck-9-","url":"https://api.github.com/repos/lisa5701/-Wanna-Fu-ck-Me-Very-Hungry-My-Pus-sy-Meet-face2face--amp--Fu-ck-9-"},"payload":{"push_id":4770748292,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"08a038be4cccec1ea5b98c40e586e77fc0dc7ac7","before":"4535d31857d19b3118e35332f01aae97b618ae27","commits":[{"sha":"08a038be4cccec1ea5b98c40e586e77fc0dc7ac7","author":{"email":"61994807+lisa5701@users.noreply.github.com","name":"lisa5701"},"message":"Add files via upload\\n\\nHi Dear??? http://realfuck69.online/number740\\r\\nI am Dezi star .Divorced older Pussy. Older woman just want a guy\\r\\nor girl to go down and eat my pussy I\'m Clean, shaved and sweet. Must be\\r\\nattractive, and I will return the favor. Any race & age are fine... If you\\r\\ninterested,....subject as ?? Free ?? please contact me.... http://realfuck69.online/number740\\r\\nLIMITED OFFER! Upgrade to Gold Access - 100% FREE!","distinct":true,"url":"https://api.github.com/repos/lisa5701/-Wanna-Fu-ck-Me-Very-Hungry-My-Pus-sy-Meet-face2face--amp--Fu-ck-9-/commits/08a038be4cccec1ea5b98c40e586e77fc0dc7ac7"}]},"public":true,"created_at":"2020-03-16T10:49:51Z"},{"id":"11775179444","type":"PullRequestReviewCommentEvent","actor":{"id":243846,"login":"ka8725","display_login":"ka8725","gravatar_id":"","url":"https://api.github.com/users/ka8725","avatar_url":"https://avatars.githubusercontent.com/u/243846?"},"repo":{"id":237831410,"name":"ka8725/monmon","url":"https://api.github.com/repos/ka8725/monmon"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/ka8725/monmon/pulls/comments/392932302","pull_request_review_id":375099225,"id":392932302,"node_id":"MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM5MjkzMjMwMg==","diff_hunk":"@@ -9,5 +10,9 @@\\n \\n puts(\'-----------------------------------------\')\\n balance.each do |key, val|","path":"main/monmon.rb","position":17,"original_position":11,"commit_id":"6940e379d9362cd96a57d21f9d2bbb685c36982a","original_commit_id":"c82d7e150f7e73b0e3ec406c13b7dcf0e67d44a5","user":{"login":"ka8725","id":243846,"node_id":"MDQ6VXNlcjI0Mzg0Ng==","avatar_url":"https://avatars0.githubusercontent.com/u/243846?v=4","gravatar_id":"","url":"https://api.github.com/users/ka8725","html_url":"https://github.com/ka8725","followers_url":"https://api.github.com/users/ka8725/followers","following_url":"https://api.github.com/users/ka8725/following{/other_user}","gists_url":"https://api.github.com/users/ka8725/gists{/gist_id}","starred_url":"https://api.github.com/users/ka8725/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ka8725/subscriptions","organizations_url":"https://api.github.com/users/ka8725/orgs","repos_url":"https://api.github.com/users/ka8725/repos","events_url":"https://api.github.com/users/ka8725/events{/privacy}","received_events_url":"https://api.github.com/users/ka8725/received_events","type":"User","site_admin":false},"body":"I don\'t see that you changed anything. The `balance` still holds both currencies with errors and without errors.","created_at":"2020-03-16T10:49:51Z","updated_at":"2020-03-16T10:49:51Z","html_url":"https://github.com/ka8725/monmon/pull/9#discussion_r392932302","pull_request_url":"https://api.github.com/repos/ka8725/monmon/pulls/9","author_association":"OWNER","_links":{"self":{"href":"https://api.github.com/repos/ka8725/monmon/pulls/comments/392932302"},"html":{"href":"https://github.com/ka8725/monmon/pull/9#discussion_r392932302"},"pull_request":{"href":"https://api.github.com/repos/ka8725/monmon/pulls/9"}},"in_reply_to_id":389410842},"pull_request":{"url":"https://api.github.com/repos/ka8725/monmon/pulls/9","id":3853187 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11775179450',
#   'type': 'PushEvent',
#   'actor': {'id': 61994807,
#    'login': 'lisa5701',
#    'display_login': 'lisa5701',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lisa5701',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61994807?'},
#   'repo': {'id': 246156410,
#    'name': 'lisa5701/-Wanna-Fu-ck-Me-Very-Hungry-My-Pus-sy-Meet-face2face--amp--Fu-ck-9-',
#    'url': 'https://api.github.com/repos/lisa5701/-Wanna-Fu-ck-Me-Very-Hungry-My-Pus-sy-Meet-face2face--amp--Fu-ck-9-'},
#   'payload': {'push_id': 4770748292,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '08a038be4cccec1ea5b98c40e586e77fc0dc7ac7',
#    'before': '4535d31857d19b3118e35332f01aae97b618ae27',
#    'commits': [{'sha': '08a038be4cccec1ea5b98c40e586e77fc0dc7ac7',
#      'author': {'email': '61994807+lisa5701@users.noreply.github.com',
#       'name': 'lisa5701'},
#      'message': "Add files via upload\n\nHi Dear??? http://realfuck69.online/number740\r\nI am Dezi star .Divorced older Pussy. Older woman just want a guy\r\nor girl to go down and eat my pussy I'm Clean, shaved and sweet. Must be\r\nattractive, and I will return the favor. Any race & age are fine... If you\r\ninterested,....subject as ?? Free ?? please contact me.... http://realfuck69.online/number740\r\nLIMITED OFFER! Upgrade to Gold Access - 100% FREE!",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lisa5701/-Wanna-Fu-ck-Me-Very-Hungry-My-Pus-sy-Meet-face2face--amp--Fu-ck-9-/commits/08a038be4cccec1ea5b98c40e586e77fc0dc7ac7'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179444',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 243846,
#    'login': 'ka8725',
#    'display_login': 'ka8725',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ka8725',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/243846?'},
#   'repo': {'id': 237831410,
#    'name': 'ka8725/monmon',
#    'url': 'https://api.github.com/repos/ka8725/monmon'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/ka8725/monmon/pulls/comments/392932302',
#     'pull_request_review_id': 375099225,
#     'id': 392932302,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM5MjkzMjMwMg==',
#     'diff_hunk': "@@ -9,5 +10,9 @@\n \n puts('-----------------------------------------')\n balance.each do |key, val|",
#     'path': 'main/monmon.rb',
#     'position': 17,
#     'original_position': 11,
#     'commit_id': '6940e379d9362cd96a57d21f9d2bbb685c36982a',
#     'original_commit_id': 'c82d7e150f7e73b0e3ec406c13b7dcf0e67d44a5',
#     'user': {'login': 'ka8725',
#      'id': 243846,
#      'node_id': 'MDQ6VXNlcjI0Mzg0Ng==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/243846?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ka8725',
#      'html_url': 'https://github.com/ka8725',
#      'followers_url': 'https://api.github.com/users/ka8725/followers',
#      'following_url': 'https://api.github.com/users/ka8725/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ka8725/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ka8725/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ka8725/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ka8725/orgs',
#      'repos_url': 'https://api.github.com/users/ka8725/repos',
#      'events_url': 'https://api.github.com/users/ka8725/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ka8725/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "I don't see that you changed anything. The `balance` still holds both currencies with errors and without errors.",
#     'created_at': '2020-03-16T10:49:51Z',
#     'updated_at': '2020-03-16T10:49:51Z',
#     'html_url': 'https://github.com/ka8725/monmon/pull/9#discussion_r392932302',
#     'pull_request_url': 'https://api.github.com/repos/ka8725/monmon/pulls/9',
#     'author_association': 'OWNER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/ka8725/monmon/pulls/comments/392932302'},
#      'html': {'href': 'https://github.com/ka8725/monmon/pull/9#discussion_r392932302'},
#      'pull_request': {'href': 'https://api.github.com/repos/ka8725/monmon/pulls/9'}},
#     'in_reply_to_id': 389410842},
#    'pull_request': {'url': 'https://api.github.com/repos/ka8725/monmon/pulls/9',
#     'id': 385318753,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg1MzE4NzUz',
#     'html_url': 'https://github.com/ka8725/monmon/pull/9',
#     'diff_url': 'https://github.com/ka8725/monmon/pull/9.diff',
#     'patch_url': 'https://github.com/ka8725/monmon/pull/9.patch',
#     'issue_url': 'https://api.github.com/repos/ka8725/monmon/issues/9',
#     'number': 9,
#     'state': 'open',
#     'locked': False,
#     'title': 'Introduce list of known maintained currencies [issue 7]',
#     'user': {'login': 'koleshkos',
#      'id': 23640391,
#      'node_id': 'MDQ6VXNlcjIzNjQwMzkx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/23640391?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/koleshkos',
#      'html_url': 'https://github.com/koleshkos',
#      'followers_url': 'https://api.github.com/users/koleshkos/followers',
#      'following_url': 'https://api.github.com/users/koleshkos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/koleshkos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/koleshkos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/koleshkos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/koleshkos/orgs',
#      'repos_url': 'https://api.github.com/users/koleshkos/repos',
#      'events_url': 'https://api.github.com/users/koleshkos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/koleshkos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "I create a constant that keeps a set of currently supported currencies: BYN, USD, EUR, RUR.\r\n\r\nI don't count in lines with not supported currencies. I collect these lines in an array and output them at the end of the program with a message saying those lines cannot be processed.",
#     'created_at': '2020-03-08T21:54:33Z',
#     'updated_at': '2020-03-16T10:49:51Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '1a97ce26ef19cda2f88b12fbf7b135e82aaf04ca',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ka8725/monmon/pulls/9/commits',
#     'review_comments_url': 'https://api.github.com/repos/ka8725/monmon/pulls/9/comments',
#     'review_comment_url': 'https://api.github.com/repos/ka8725/monmon/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ka8725/monmon/issues/9/comments',
#     'statuses_url': 'https://api.github.com/repos/ka8725/monmon/statuses/6940e379d9362cd96a57d21f9d2bbb685c36982a',
#     'head': {'label': 'ka8725:iss7',
#      'ref': 'iss7',
#      'sha': '6940e379d9362cd96a57d21f9d2bbb685c36982a',
#      'user': {'login': 'ka8725',
#       'id': 243846,
#       'node_id': 'MDQ6VXNlcjI0Mzg0Ng==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/243846?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ka8725',
#       'html_url': 'https://github.com/ka8725',
#       'followers_url': 'https://api.github.com/users/ka8725/followers',
#       'following_url': 'https://api.github.com/users/ka8725/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ka8725/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ka8725/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ka8725/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ka8725/orgs',
#       'repos_url': 'https://api.github.com/users/ka8725/repos',
#       'events_url': 'https://api.github.com/users/ka8725/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ka8725/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 237831410,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzc4MzE0MTA=',
#       'name': 'monmon',
#       'full_name': 'ka8725/monmon',
#       'private': False,
#       'owner': {'login': 'ka8725',
#        'id': 243846,
#        'node_id': 'MDQ6VXNlcjI0Mzg0Ng==',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/243846?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ka8725',
#        'html_url': 'https://github.com/ka8725',
#        'followers_url': 'https://api.github.com/users/ka8725/followers',
#        'following_url': 'https://api.github.com/users/ka8725/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ka8725/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ka8725/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ka8725/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ka8725/orgs',
#        'repos_url': 'https://api.github.com/users/ka8725/repos',
#        'events_url': 'https://api.github.com/users/ka8725/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ka8725/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ka8725/monmon',
#       'description': 'A personal Financial Manager: Reserve Fund, Money, Investment, Assets, Financial Plan',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ka8725/monmon',
#       'forks_url': 'https://api.github.com/repos/ka8725/monmon/forks',
#       'keys_url': 'https://api.github.com/repos/ka8725/monmon/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ka8725/monmon/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ka8725/monmon/teams',
#       'hooks_url': 'https://api.github.com/repos/ka8725/monmon/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ka8725/monmon/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ka8725/monmon/events',
#       'assignees_url': 'https://api.github.com/repos/ka8725/monmon/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ka8725/monmon/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ka8725/monmon/tags',
#       'blobs_url': 'https://api.github.com/repos/ka8725/monmon/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ka8725/monmon/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ka8725/monmon/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ka8725/monmon/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ka8725/monmon/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ka8725/monmon/languages',
#       'stargazers_url': 'https://api.github.com/repos/ka8725/monmon/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ka8725/monmon/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ka8725/monmon/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ka8725/monmon/subscription',
#       'commits_url': 'https://api.github.com/repos/ka8725/monmon/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ka8725/monmon/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ka8725/monmon/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ka8725/monmon/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ka8725/monmon/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ka8725/monmon/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ka8725/monmon/merges',
#       'archive_url': 'https://api.github.com/repos/ka8725/monmon/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ka8725/monmon/downloads',
#       'issues_url': 'https://api.github.com/repos/ka8725/monmon/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ka8725/monmon/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ka8725/monmon/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ka8725/monmon/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ka8725/monmon/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ka8725/monmon/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ka8725/monmon/deployments',
#       'created_at': '2020-02-02T20:24:09Z',
#       'updated_at': '2020-03-05T10:50:50Z',
#       'pushed_at': '2020-03-15T22:44:58Z',
#       'git_url': 'git://github.com/ka8725/monmon.git',
#       'ssh_url': 'git@github.com:ka8725/monmon.git',
#       'clone_url': 'https://github.com/ka8725/monmon.git',
#       'svn_url': 'https://github.com/ka8725/monmon',
#       'homepage': 'http://tobe.created',
#       'size': 5,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': None,
#       'forks': 0,
#       'open_issues': 8,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ka8725:master',
#      'ref': 'master',
#      'sha': '8b82a25b13dcf541c9fb6b247a0d0f39b9f62c54',
#      'user': {'login': 'ka8725',
#       'id': 243846,
#       'node_id': 'MDQ6VXNlcjI0Mzg0Ng==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/243846?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ka8725',
#       'html_url': 'https://github.com/ka8725',
#       'followers_url': 'https://api.github.com/users/ka8725/followers',
#       'following_url': 'https://api.github.com/users/ka8725/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ka8725/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ka8725/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ka8725/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ka8725/orgs',
#       'repos_url': 'https://api.github.com/users/ka8725/repos',
#       'events_url': 'https://api.github.com/users/ka8725/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ka8725/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 237831410,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzc4MzE0MTA=',
#       'name': 'monmon',
#       'full_name': 'ka8725/monmon',
#       'private': False,
#       'owner': {'login': 'ka8725',
#        'id': 243846,
#        'node_id': 'MDQ6VXNlcjI0Mzg0Ng==',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/243846?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ka8725',
#        'html_url': 'https://github.com/ka8725',
#        'followers_url': 'https://api.github.com/users/ka8725/followers',
#        'following_url': 'https://api.github.com/users/ka8725/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ka8725/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ka8725/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ka8725/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ka8725/orgs',
#        'repos_url': 'https://api.github.com/users/ka8725/repos',
#        'events_url': 'https://api.github.com/users/ka8725/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ka8725/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ka8725/monmon',
#       'description': 'A personal Financial Manager: Reserve Fund, Money, Investment, Assets, Financial Plan',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ka8725/monmon',
#       'forks_url': 'https://api.github.com/repos/ka8725/monmon/forks',
#       'keys_url': 'https://api.github.com/repos/ka8725/monmon/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ka8725/monmon/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ka8725/monmon/teams',
#       'hooks_url': 'https://api.github.com/repos/ka8725/monmon/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ka8725/monmon/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ka8725/monmon/events',
#       'assignees_url': 'https://api.github.com/repos/ka8725/monmon/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ka8725/monmon/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ka8725/monmon/tags',
#       'blobs_url': 'https://api.github.com/repos/ka8725/monmon/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ka8725/monmon/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ka8725/monmon/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ka8725/monmon/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ka8725/monmon/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ka8725/monmon/languages',
#       'stargazers_url': 'https://api.github.com/repos/ka8725/monmon/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ka8725/monmon/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ka8725/monmon/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ka8725/monmon/subscription',
#       'commits_url': 'https://api.github.com/repos/ka8725/monmon/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ka8725/monmon/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ka8725/monmon/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ka8725/monmon/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ka8725/monmon/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ka8725/monmon/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ka8725/monmon/merges',
#       'archive_url': 'https://api.github.com/repos/ka8725/monmon/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ka8725/monmon/downloads',
#       'issues_url': 'https://api.github.com/repos/ka8725/monmon/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ka8725/monmon/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ka8725/monmon/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ka8725/monmon/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ka8725/monmon/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ka8725/monmon/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ka8725/monmon/deployments',
#       'created_at': '2020-02-02T20:24:09Z',
#       'updated_at': '2020-03-05T10:50:50Z',
#       'pushed_at': '2020-03-15T22:44:58Z',
#       'git_url': 'git://github.com/ka8725/monmon.git',
#       'ssh_url': 'git@github.com:ka8725/monmon.git',
#       'clone_url': 'https://github.com/ka8725/monmon.git',
#       'svn_url': 'https://github.com/ka8725/monmon',
#       'homepage': 'http://tobe.created',
#       'size': 5,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': None,
#       'forks': 0,
#       'open_issues': 8,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ka8725/monmon/pulls/9'},
#      'html': {'href': 'https://github.com/ka8725/monmon/pull/9'},
#      'issue': {'href': 'https://api.github.com/repos/ka8725/monmon/issues/9'},
#      'comments': {'href': 'https://api.github.com/repos/ka8725/monmon/issues/9/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ka8725/monmon/pulls/9/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ka8725/monmon/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ka8725/monmon/pulls/9/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ka8725/monmon/statuses/6940e379d9362cd96a57d21f9d2bbb685c36982a'}},
#     'author_association': 'COLLABORATOR'}},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179426',
#   'type': 'PushEvent',
#   'actor': {'id': 21954590,
#    'login': 'elife-bot',
#    'display_login': 'elife-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elife-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21954590?'},
#   'repo': {'id': 69345821,
#    'name': 'elifesciences/elife-article-xml-end2end',
#    'url': 'https://api.github.com/repos/elifesciences/elife-article-xml-end2end'},
#   'payload': {'push_id': 4770748286,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3de2ace8b52f011fb524f41b73a1c7c65b763e83',
#    'before': 'b5a1bfdedde00d2dd8f765bb54c17d71178a7e6a',
#    'commits': [{'sha': '3de2ace8b52f011fb524f41b73a1c7c65b763e83',
#      'author': {'email': 'elife-bot@elifesciences.org', 'name': 'elife-bot'},
#      'message': 'Creates XML',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/elifesciences/elife-article-xml-end2end/commits/3de2ace8b52f011fb524f41b73a1c7c65b763e83'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 1777367,
#    'login': 'elifesciences',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/elifesciences',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1777367?'}},
#  {'id': '11775179434',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 7240,
#    'login': 'fcm',
#    'display_login': 'fcm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fcm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7240?'},
#   'repo': {'id': 199627212,
#    'name': 'arthurd2/plataforma-for',
#    'url': 'https://api.github.com/repos/arthurd2/plataforma-for'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/arthurd2/plataforma-for/comments/37847373',
#     'html_url': 'https://github.com/arthurd2/plataforma-for/commit/bf7c403ea114c9799ea6d2e07ac16071a0899151#commitcomment-37847373',
#     'id': 37847373,
#     'node_id': 'MDEzOkNvbW1pdENvbW1lbnQzNzg0NzM3Mw==',
#     'user': {'login': 'fcm',
#      'id': 7240,
#      'node_id': 'MDQ6VXNlcjcyNDA=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/7240?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/fcm',
#      'html_url': 'https://github.com/fcm',
#      'followers_url': 'https://api.github.com/users/fcm/followers',
#      'following_url': 'https://api.github.com/users/fcm/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/fcm/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/fcm/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/fcm/subscriptions',
#      'organizations_url': 'https://api.github.com/users/fcm/orgs',
#      'repos_url': 'https://api.github.com/users/fcm/repos',
#      'events_url': 'https://api.github.com/users/fcm/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/fcm/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'position': 5,
#     'line': 4,
#     'path': 'frontend-web/Dockerfile',
#     'commit_id': 'bf7c403ea114c9799ea6d2e07ac16071a0899151',
#     'created_at': '2020-03-16T10:49:51Z',
#     'updated_at': '2020-03-16T10:49:51Z',
#     'author_association': 'NONE',
#     'body': 'Show resolveu o problema que acontecia https://github.com/forpdi/plataforma-for/issues/283#issuecomment-599073680'}},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179425',
#   'type': 'CreateEvent',
#   'actor': {'id': 55150088,
#    'login': 'duclotm',
#    'display_login': 'duclotm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/duclotm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55150088?'},
#   'repo': {'id': 247653663,
#    'name': 'duclotm/marie_rs_test',
#    'url': 'https://api.github.com/repos/duclotm/marie_rs_test'},
#   'payload': {'ref': 'hpa_template_selection_toggle',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'test before rs migration',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179429',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 199141860,
#    'name': 'forever-Liudawang/movieProject',
#    'url': 'https://api.github.com/repos/forever-Liudawang/movieProject'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/acorn-5.7.4',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179419',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 2354108,
#    'login': 'coveralls',
#    'display_login': 'coveralls',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/coveralls',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2354108?'},
#   'repo': {'id': 144256157,
#    'name': 'chevre-jp/api-abstract-client',
#    'url': 'https://api.github.com/repos/chevre-jp/api-abstract-client'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/issues/2',
#     'repository_url': 'https://api.github.com/repos/chevre-jp/api-abstract-client',
#     'labels_url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/issues/2/comments',
#     'events_url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/issues/2/events',
#     'html_url': 'https://github.com/chevre-jp/api-abstract-client/pull/2',
#     'id': 582191549,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg5MTQ3Mzcw',
#     'number': 2,
#     'title': 'Bump acorn from 5.7.3 to 5.7.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1645962739,
#       'node_id': 'MDU6TGFiZWwxNjQ1OTYyNzM5',
#       'url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-16T10:48:59Z',
#     'updated_at': '2020-03-16T10:49:51Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/pulls/2',
#      'html_url': 'https://github.com/chevre-jp/api-abstract-client/pull/2',
#      'diff_url': 'https://github.com/chevre-jp/api-abstract-client/pull/2.diff',
#      'patch_url': 'https://github.com/chevre-jp/api-abstract-client/pull/2.patch'},
#     'body': 'Bumps [acorn](https://github.com/acornjs/acorn) from 5.7.3 to 5.7.4.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/acornjs/acorn/commit/6370e90067552022710190319cbbbd8c43001957"><code>6370e90</code></a> Mark version 5.7.4</li>\n<li><a href="https://github.com/acornjs/acorn/commit/fbc15b1344f6dfb992f67b4bbf1357436247c8a0"><code>fbc15b1</code></a> More rigorously check surrogate pairs in regexp validator</li>\n<li>See full diff in <a href="https://github.com/acornjs/acorn/compare/5.7.3...5.7.4">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=acorn&package-manager=npm_and_yarn&previous-version=5.7.3&new-version=5.7.4)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/chevre-jp/api-abstract-client/network/alerts).\n\n</details>'},
#    'comment': {'url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/issues/comments/599469228',
#     'html_url': 'https://github.com/chevre-jp/api-abstract-client/pull/2#issuecomment-599469228',
#     'issue_url': 'https://api.github.com/repos/chevre-jp/api-abstract-client/issues/2',
#     'id': 599469228,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5OTQ2OTIyOA==',
#     'user': {'login': 'coveralls',
#      'id': 2354108,
#      'node_id': 'MDQ6VXNlcjIzNTQxMDg=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/2354108?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/coveralls',
#      'html_url': 'https://github.com/coveralls',
#      'followers_url': 'https://api.github.com/users/coveralls/followers',
#      'following_url': 'https://api.github.com/users/coveralls/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/coveralls/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/coveralls/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/coveralls/subscriptions',
#      'organizations_url': 'https://api.github.com/users/coveralls/orgs',
#      'repos_url': 'https://api.github.com/users/coveralls/repos',
#      'events_url': 'https://api.github.com/users/coveralls/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/coveralls/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-03-16T10:49:51Z',
#     'updated_at': '2020-03-16T10:49:51Z',
#     'author_association': 'NONE',
#     'body': '## Pull Request Test Coverage Report for [Build 960](https://coveralls.io/builds/29380620)\n\n* **0** of **0**   changed or added relevant lines in **0** files are covered.\n* No unchanged relevant lines lost coverage.\n* Overall coverage remained the same at **100.0%**\n\n---\n\n\n\n|  Totals | [![Coverage Status](https://coveralls.io/builds/29380620/badge)](https://coveralls.io/builds/29380620) |\n| :-- | --: |\n| Change from base [Build 675](https://coveralls.io/builds/26526837): |  0.0% |\n| Covered Lines: | 60 |\n| Relevant Lines: | 60 |\n\n---\n##### 💛  - [Coveralls](https://coveralls.io)\n'}},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 42127204,
#    'login': 'chevre-jp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/chevre-jp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42127204?'}},
#  {'id': '11775179411',
#   'type': 'PushEvent',
#   'actor': {'id': 2972950,
#    'login': 'andryyy',
#    'display_login': 'andryyy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andryyy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2972950?'},
#   'repo': {'id': 89955680,
#    'name': 'mailcow/mailcow-dockerized-docs',
#    'url': 'https://api.github.com/repos/mailcow/mailcow-dockerized-docs'},
#   'payload': {'push_id': 4770748281,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': '2140e9814a47a6c96b5b86464fd2235e6f9bdffa',
#    'before': '213a3aa78a0f12d408f14c13c5258935c4ca30ec',
#    'commits': [{'sha': '12d1d9767fb93714437e7a074278d5105c546bd1',
#      'author': {'email': '33233376+Gaming4LifeDE@users.noreply.github.com',
#       'name': 'Sebastian Kutter'},
#      'message': 'Updated Prerequisites\n\nThe file was edited to remove the outdated (and in some cases removed) `netstat` command and replace it with `ss`',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mailcow/mailcow-dockerized-docs/commits/12d1d9767fb93714437e7a074278d5105c546bd1'},
#     {'sha': '75bdbdc7dfa541bc5e7ef644fefd45af258af639',
#      'author': {'email': 'andre.peters@debinux.de', 'name': 'André Peters'},
#      'message': 'Update prerequisite-system.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mailcow/mailcow-dockerized-docs/commits/75bdbdc7dfa541bc5e7ef644fefd45af258af639'},
#     {'sha': '2140e9814a47a6c96b5b86464fd2235e6f9bdffa',
#      'author': {'email': 'andre.peters@debinux.de', 'name': 'André Peters'},
#      'message': 'Merge pull request #201 from Gaming4LifeDE/patch-1\n\nUpdated Prerequisites',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mailcow/mailcow-dockerized-docs/commits/2140e9814a47a6c96b5b86464fd2235e6f9bdffa'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 23747925,
#    'login': 'mailcow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mailcow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23747925?'}},
#  {'id': '11775179410',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197735731,
#    'name': 'adeo-gitlab/sync-github-gitlab-25',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-25'},
#   'payload': {'ref': '2020-03-16_10-49-39_621_scenario1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '11775179400',
#   'type': 'PushEvent',
#   'actor': {'id': 22259669,
#    'login': 'CPlusPlusTW',
#    'display_login': 'CPlusPlusTW',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CPlusPlusTW',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22259669?'},
#   'repo': {'id': 216352536,
#    'name': 'CPlusPlusTW/libScreenCapture',
#    'url': 'https://api.github.com/repos/CPlusPlusTW/libScreenCapture'},
#   'payload': {'push_id': 4770748273,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '21bec981991ff8c8c6bce73971bac010b001b551',
#    'before': 'bd105c45bdc4b56cdf0b58e619bd8a2e734dd187',
#    'commits': [{'sha': '21bec981991ff8c8c6bce73971bac010b001b551',
#      'author': {'email': 'cplusplus.tw@gmail.com', 'name': 'Jim Huang'},
#      'message': 'Add dependencies for win10',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CPlusPlusTW/libScreenCapture/commits/21bec981991ff8c8c6bce73971bac010b001b551'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179402',
#   'type': 'PushEvent',
#   'actor': {'id': 47658341,
#    'login': 'shayandaneshvar',
#    'display_login': 'shayandaneshvar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shayandaneshvar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47658341?'},
#   'repo': {'id': 247294032,
#    'name': 'java-kntu-982/p2-tour-management-mamal007',
#    'url': 'https://api.github.com/repos/java-kntu-982/p2-tour-management-mamal007'},
#   'payload': {'push_id': 4770748276,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9ab6ded10d3c665638a367106c3203cff9ab6633',
#    'before': '4a4426a9ab796e9179555ea2c5d4f465c1e18681',
#    'commits': [{'sha': '9ab6ded10d3c665638a367106c3203cff9ab6633',
#      'author': {'email': 'daneshvarshayan@gmail.com',
#       'name': 'Seyyed Shayan Daneshvar'},
#      'message': 'Update pom.xml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/java-kntu-982/p2-tour-management-mamal007/commits/9ab6ded10d3c665638a367106c3203cff9ab6633'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 60741492,
#    'login': 'java-kntu-982',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/java-kntu-982',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60741492?'}},
#  {'id': '11775179383',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 247496356,
#    'name': 'dapplion/Ethereum-Mainnet-Blocks',
#    'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks'},
#   'payload': {'push_id': 4770748249,
#    'size': 50,
#    'distinct_size': 50,
#    'ref': 'refs/heads/master',
#    'head': 'f5e6d50bbecf45add2cbd7723d0c38f703fa67a5',
#    'before': 'c91fbf7bee5d3007e1339af128f07b730125ac02',
#    'commits': [{'sha': 'a0513b316f85e8c48d6a790813b15b71cd0834d0',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90551',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/a0513b316f85e8c48d6a790813b15b71cd0834d0'},
#     {'sha': 'cc27c620c04981de858a7d4eae252f8d586fa504',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90552',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/cc27c620c04981de858a7d4eae252f8d586fa504'},
#     {'sha': 'e963c24f9842afadd73a84e68326c02ee49c1076',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90553',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/e963c24f9842afadd73a84e68326c02ee49c1076'},
#     {'sha': '37892ec2441b2632838a7ddb2dd31aeac76c82a0',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90554',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/37892ec2441b2632838a7ddb2dd31aeac76c82a0'},
#     {'sha': 'df82c45e1925df9396e002cd471014da72d07806',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90555',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/df82c45e1925df9396e002cd471014da72d07806'},
#     {'sha': 'e7426b1ed8902e561072ffdf25a82e1089c53a33',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90556',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/e7426b1ed8902e561072ffdf25a82e1089c53a33'},
#     {'sha': '861abada5351de1537d007e5b28caac9f912aba7',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90557',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/861abada5351de1537d007e5b28caac9f912aba7'},
#     {'sha': 'b548f52d3d0e11d15dc58d427976f13b03669e9f',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90558',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/b548f52d3d0e11d15dc58d427976f13b03669e9f'},
#     {'sha': 'cace99e366d6974562554f994bc40ac6d9aecc97',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90559',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/cace99e366d6974562554f994bc40ac6d9aecc97'},
#     {'sha': 'aa9f4906bbfcacb911a8b5ad43ab9674818c17bd',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90560',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/aa9f4906bbfcacb911a8b5ad43ab9674818c17bd'},
#     {'sha': '51120dbcb047a8d39f4f42e46566f6a7ab19fcc3',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90561',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/51120dbcb047a8d39f4f42e46566f6a7ab19fcc3'},
#     {'sha': '9b295a8552bdcf506369dceb30ec2e4212aefc87',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90562',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/9b295a8552bdcf506369dceb30ec2e4212aefc87'},
#     {'sha': 'ce2e5dbfea6d5d5b4181cad8695a79d85d0acbb2',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90563',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/ce2e5dbfea6d5d5b4181cad8695a79d85d0acbb2'},
#     {'sha': 'cf43b1de78804066bbec73b3ac2cf19cbedf8111',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90564',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/cf43b1de78804066bbec73b3ac2cf19cbedf8111'},
#     {'sha': 'd651a47683516011026112df6d15ae6cc2b5b750',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90565',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/d651a47683516011026112df6d15ae6cc2b5b750'},
#     {'sha': '067cf3833214501ecb2fffa3194fc3bec67e69a9',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90566',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/067cf3833214501ecb2fffa3194fc3bec67e69a9'},
#     {'sha': 'c47de5f947a0b5b220e189adaffb548d614fe4ee',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90567',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/c47de5f947a0b5b220e189adaffb548d614fe4ee'},
#     {'sha': 'dca9210e913f6a9249429818ae836c58bca3d63d',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90568',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/dca9210e913f6a9249429818ae836c58bca3d63d'},
#     {'sha': 'a6dc9dfec9288c146a106925b75ff50efd7036af',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90569',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/a6dc9dfec9288c146a106925b75ff50efd7036af'},
#     {'sha': 'a22cc6dae6b4372e79b4f00aead13f787a18fd8f',
#      'author': {'email': 'actions@github.com', 'name': 'Github'},
#      'message': 'Add block 90570',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dapplion/Ethereum-Mainnet-Blocks/commits/a22cc6dae6b4372e79b4f00aead13f787a18fd8f'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179366',
#   'type': 'PushEvent',
#   'actor': {'id': 8525754,
#    'login': 'TanninOne',
#    'display_login': 'TanninOne',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TanninOne',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8525754?'},
#   'repo': {'id': 121662010,
#    'name': 'Nexus-Mods/extension-mod-dependencies',
#    'url': 'https://api.github.com/repos/Nexus-Mods/extension-mod-dependencies'},
#   'payload': {'push_id': 4770748257,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '36088bf75337b182dc19181fced31bcbc4fb16ca',
#    'before': '341de0142ea83eebcb4a9ff9883430c11a12d834',
#    'commits': [{'sha': '36088bf75337b182dc19181fced31bcbc4fb16ca',
#      'author': {'email': 'seppleviathan@gmx.de', 'name': 'TanninOne'},
#      'message': 'updated dependencies',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Nexus-Mods/extension-mod-dependencies/commits/36088bf75337b182dc19181fced31bcbc4fb16ca'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 17085531,
#    'login': 'Nexus-Mods',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Nexus-Mods',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17085531?'}},
#  {'id': '11775179373',
#   'type': 'PushEvent',
#   'actor': {'id': 31858072,
#    'login': 'TalibAzir',
#    'display_login': 'TalibAzir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TalibAzir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31858072?'},
#   'repo': {'id': 103155160,
# ...
#      'commits': {'href': 'https://api.github.com/repos/goblin-laboratory/reactjs-player/pulls/171/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/goblin-laboratory/reactjs-player/statuses/7a2d9c386487ee8ba6126974f523cf195e4e1586'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 14369,
#     'deletions': 14245,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 41275647,
#    'login': 'goblin-laboratory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/goblin-laboratory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41275647?'}},
#  {'id': '11775179336',
#   'type': 'WatchEvent',
#   'actor': {'id': 60006267,
#    'login': '13692384128',
#    'display_login': '13692384128',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/13692384128',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60006267?'},
#   'repo': {'id': 228858304,
#    'name': 'Aquarius223/Xiaomi_Kernel_OpenSource',
#    'url': 'https://api.github.com/repos/Aquarius223/Xiaomi_Kernel_OpenSource'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179329',
#   'type': 'CreateEvent',
#   'actor': {'id': 62242429,
#    'login': 'visal-98',
#    'display_login': 'visal-98',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/visal-98',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62242429?'},
#   'repo': {'id': 247677698,
#    'name': 'visal-98/visal',
#    'url': 'https://api.github.com/repos/visal-98/visal'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179323',
#   'type': 'PushEvent',
#   'actor': {'id': 62237070,
#    'login': 'whidyamaharani',
#    'display_login': 'whidyamaharani',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/whidyamaharani',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62237070?'},
#   'repo': {'id': 247676630,
#    'name': 'whidyamaharani/WhidyaMaharani_19.11.3148',
#    'url': 'https://api.github.com/repos/whidyamaharani/WhidyaMaharani_19.11.3148'},
#   'payload': {'push_id': 4770748227,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'baf045797d997e6b95271d796eb08fe8091b119c',
#    'before': '7170665588f430596a61dbb2845edb2b64b01345',
#    'commits': [{'sha': 'baf045797d997e6b95271d796eb08fe8091b119c',
#      'author': {'email': '62237070+whidyamaharani@users.noreply.github.com',
#       'name': 'whidyamaharani'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/whidyamaharani/WhidyaMaharani_19.11.3148/commits/baf045797d997e6b95271d796eb08fe8091b119c'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z'},
#  {'id': '11775179318',
#   'type': 'PushEvent',
#   'actor': {'id': 44866271,
#    'login': 'CoenZuijderwijk',
#    'display_login': 'CoenZuijderwijk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CoenZuijderwijk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44866271?'},
#   'repo': {'id': 239538358,
#    'name': 'ThomasVanRijn/Koi-Kas',
#    'url': 'https://api.github.com/repos/ThomasVanRijn/Koi-Kas'},
#   'payload': {'push_id': 4770748224,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/master',
#    'head': '664a87fcddb55155f766840eb0a5b05c3a037144',
#    'before': '2c38f08c5e1ae2b330ec767b9224851471bf92a1',
#    'commits': [{'sha': '2a97ac61ba118f4db4621a6dc8dc4209f3f0fae2',
#      'author': {'email': '302323979@student.rocmondriaan.nl',
#       'name': 'CoenZuijderwijk'},
#      'message': 'pull',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ThomasVanRijn/Koi-Kas/commits/2a97ac61ba118f4db4621a6dc8dc4209f3f0fae2'},
#     {'sha': '49632fa7bb41eb05d04fb44ab09af3e3b44cdbb7',
#      'author': {'email': '302323979@student.rocmondriaan.nl',
#       'name': 'CoenZuijderwijk'},
#      'message': "Merge branch 'master' of https://github.com/ThomasVanRijn/Koi-Kas",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ThomasVanRijn/Koi-Kas/commits/49632fa7bb41eb05d04fb44ab09af3e3b44cdbb7'},
#     {'sha': 'dbac0209de236d83d7b1c49cb9ed954e938a7b59',
#      'author': {'email': '302323979@student.rocmondriaan.nl',
#       'name': 'CoenZuijderwijk'},
#      'message': 'pull',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ThomasVanRijn/Koi-Kas/commits/dbac0209de236d83d7b1c49cb9ed954e938a7b59'},
#     {'sha': '46d594f8a8b711f2a77d6d686b11db0e6f5e3823',
#      'author': {'email': '302323979@student.rocmondriaan.nl',
#       'name': 'CoenZuijderwijk'},
#      'message': "Merge branch 'master' of https://github.com/ThomasVanRijn/Koi-Kas",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ThomasVanRijn/Koi-Kas/commits/46d594f8a8b711f2a77d6d686b11db0e6f5e3823'},
#     {'sha': '664a87fcddb55155f766840eb0a5b05c3a037144',
#      'author': {'email': '302323979@student.rocmondriaan.nl',
#       'name': 'CoenZuijderwijk'},
#      'message': 'commit thomas weet hoe en wat',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ThomasVanRijn/Koi-Kas/commits/664a87fcddb55155f766840eb0a5b05c3a037144'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:50Z'},
#  {'id': '11775179327',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41165336,
#    'login': 'render[bot]',
#    'display_login': 'render',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/render[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41165336?'},
#   'repo': {'id': 226300769,
#    'name': 'bandprotocol/bandchain',
#    'url': 'https://api.github.com/repos/bandprotocol/bandchain'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/bandprotocol/bandchain/issues/865',
#     'repository_url': 'https://api.github.com/repos/bandprotocol/bandchain',
#     'labels_url': 'https://api.github.com/repos/bandprotocol/bandchain/issues/865/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/bandprotocol/bandchain/issues/865/comments',
#     'events_url': 'https://api.github.com/repos/bandprotocol/bandchain/issues/865/events',
#     'html_url': 'https://github.com/bandprotocol/bandchain/pull/865',
#     'id': 582192067,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg5MTQ3ODA4',
#     'number': 865,
#     'title': 'Implement oracle script index execution tab ui',
#     'user': {'login': 'prin-r',
#      'id': 12705423,
#      'node_id': 'MDQ6VXNlcjEyNzA1NDIz',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/12705423?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/prin-r',
#      'html_url': 'https://github.com/prin-r',
#      'followers_url': 'https://api.github.com/users/prin-r/followers',
#      'following_url': 'https://api.github.com/users/prin-r/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/prin-r/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/prin-r/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/prin-r/subscriptions',
#      'organizations_url': 'https://api.github.com/users/prin-r/orgs',
#      'repos_url': 'https://api.github.com/users/prin-r/repos',
#      'events_url': 'https://api.github.com/users/prin-r/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/prin-r/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-16T10:49:48Z',
#     'updated_at': '2020-03-16T10:49:50Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'pull_request': {'url': 'https://api.github.com/repos/bandprotocol/bandchain/pulls/865',
#      'html_url': 'https://github.com/bandprotocol/bandchain/pull/865',
#      'diff_url': 'https://github.com/bandprotocol/bandchain/pull/865.diff',
#      'patch_url': 'https://github.com/bandprotocol/bandchain/pull/865.patch'},
#     'body': 'Fix #835 '},
#    'comment': {'url': 'https://api.github.com/repos/bandprotocol/bandchain/issues/comments/599469225',
#     'html_url': 'https://github.com/bandprotocol/bandchain/pull/865#issuecomment-599469225',
#     'issue_url': 'https://api.github.com/repos/bandprotocol/bandchain/issues/865',
#     'id': 599469225,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5OTQ2OTIyNQ==',
#     'user': {'login': 'render[bot]',
#      'id': 41165336,
#      'node_id': 'MDM6Qm90NDExNjUzMzY=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/in/14658?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/render%5Bbot%5D',
#      'html_url': 'https://github.com/apps/render',
#      'followers_url': 'https://api.github.com/users/render%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/render%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/render%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/render%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/render%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/render%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/render%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/render%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/render%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-03-16T10:49:50Z',
#     'updated_at': '2020-03-16T10:49:50Z',
#     'author_association': 'NONE',
#     'body': 'Your [Render](https://render.com) PR Server URL is https://d3n-scan-pr-865.onrender.com.\n\nFollow its progress at https://dashboard.render.com/static/srv-bpnljjf8jd5tff0vf7a0.'}},
#   'public': True,
#   'created_at': '2020-03-16T10:49:51Z',
#   'org': {'id': 39086992,
#    'login': 'bandprotocol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bandprotocol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39086992?'}},
#  {'id': '11775179319',
#   'type': 'PushEvent',
#   'actor': {'id': 47849626,
#    'login': 'miguelsoaresking500',
#    'display_login': 'miguelsoaresking500',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/miguelsoaresking500',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47849626?'},
#   'repo': {'id': 237975295,
#    'name': 'samuelroland/CSUNVBA2',
#    'url': 'https://api.github.com/repos/samuelroland/CSUNVBA2'},
#   'payload': {'push_id': 4770748226,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7b8bba5615cd89bcfe02530f7773887309eda919',
#    'before': '9778898d9a0d1e87ab0b305c0c521fc41ad57dd8',
#    'commits': [{'sha': '7b8bba5615cd89bcfe02530f7773887309eda919',
#      'author': {'email': '47849626+miguelsoaresking500@users.noreply.github.com',
#       'name': 'Miguel Soares'},
#      'message': 'minimal changes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/samuelroland/CSUNVBA2/commits/7b8bba5615cd89bcfe02530f7773887309eda919'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:50Z'},
#  {'id': '11775179306',
#   'type': 'PushEvent',
#   'actor': {'id': 10437176,
#    'login': 'meg1502',
#    'display_login': 'meg1502',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meg1502',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10437176?'},
#   'repo': {'id': 35801650,
#    'name': 'scireum/sirius-biz',
#    'url': 'https://api.github.com/repos/scireum/sirius-biz'},
#   'payload': {'push_id': 4770748217,
#    'size': 6,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0fd47280ee5d4b5a319ad5787402dc9584a9475e',
#    'before': '5a5de38c27711f03c1540f5ef59e453c85b73bf5',
#    'commits': [{'sha': '2d51be02755762e439d6dfb9158e4760791de9a7',
#      'author': {'email': 'aha@scireum.de', 'name': 'aha'},
#      'message': 'Provides VirtualFile.download()\n\nThis will yield a FileHandle to directly access the contents of the\nwrapped file. By default a temporary file will be created and\nand used. However, some roots might provide a direct way\nof accessing a file (e.g. when working on local files already).',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/scireum/sirius-biz/commits/2d51be02755762e439d6dfb9158e4760791de9a7'},
#     {'sha': '0d47f237bf9d011a1c85b0105aa3ff139e507009',
#      'author': {'email': 'aha@scireum.de', 'name': 'aha'},
#      'message': 'Adds an additional method for attaching a file.\n\nIf the contents of a file are already available as FileHandle,\nwe can directly use this. Using a remote storage like S3\nthis might save us from downloading the same file twice.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/scireum/sirius-biz/commits/0d47f237bf9d011a1c85b0105aa3ff139e507009'},
#     {'sha': '77e5c349b589b743b5fa18cb310277d3898839f4',
#      'author': {'email': 'aha@scireum.de', 'name': 'aha'},
#      'message': "BREAKING: Uses a FileHandle to prevent duplicate downloads of the file being processed.\n\nIf we're using a remote storage we previously downloaded the same file twice\n(first to attach it, then to process it). We're now making a local copy and use\nthis for both steps.\n\nThis is a breaking change as the internal API changed for subclasses.",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/scireum/sirius-biz/commits/77e5c349b589b743b5fa18cb310277d3898839f4'},
#     {'sha': '542757e8494c91b22d8d9f380da4c0492757fcf2',
#      'author': {'email': 'aha@scireum.de', 'name': 'aha'},
#      'message': 'Organizes imports.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/scireum/sirius-biz/commits/542757e8494c91b22d8d9f380da4c0492757fcf2'},
#     {'sha': '69075fc8ea0b3f8f614ccfa54e2a45ad55dd06c8',
#      'author': {'email': 'aha@scireum.de', 'name': 'aha'},
#      'message': "Merge remote-tracking branch 'origin/master' into aha/vfs-download",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/scireum/sirius-biz/commits/69075fc8ea0b3f8f614ccfa54e2a45ad55dd06c8'},
#     {'sha': '0fd47280ee5d4b5a319ad5787402dc9584a9475e',
#      'author': {'email': 'meg@scireum.de', 'name': 'meg1502'},
#      'message': 'Merge pull request #697 from scireum/aha/vfs-download\n\nAdds VirtualFile.download and uses it in the FileImportJob',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/scireum/sirius-biz/commits/0fd47280ee5d4b5a319ad5787402dc9584a9475e'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:50Z',
#   'org': {'id': 5050602,
#    'login': 'scireum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/scireum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5050602?'}},
#  {'id': '11775179316',
#   'type': 'PushEvent',
#   'actor': {'id': 62028064,
#    'login': 'LGJ-lee',
#    'display_login': 'LGJ-lee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LGJ-lee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62028064?'},
#   'repo': {'id': 246359144,
#    'name': 'LGJ-lee/-db',
#    'url': 'https://api.github.com/repos/LGJ-lee/-db'},
#   'payload': {'push_id': 4770748216,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '00096b100ca4bc4c7488d70484b0ee65bb096116',
#    'before': '78345c38e1aa94e9e17a3459997235b0a1eab0b0',
#    'commits': [{'sha': '00096b100ca4bc4c7488d70484b0ee65bb096116',
#      'author': {'email': '62028064+LGJ-lee@users.noreply.github.com',
#       'name': 'LGJ-lee'},
#      'message': 'kill list',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LGJ-lee/-db/commits/00096b100ca4bc4c7488d70484b0ee65bb096116'}]},
#   'public': True,
#   'created_at': '2020-03-16T10:49:50Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
'''
Your Code
'''
import requests

r1 = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r1.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H029","WaterLevel": 145.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H070","WaterLevel": 226.25},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H021","WaterLevel": 1.28},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H017","WaterLevel": 25.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2560H019","WaterLevel": 4.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H001","WaterLevel": 224.21},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H075","WaterLevel": 92.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H036","WaterLevel": 164.37},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2500H003","WaterLevel": 32.2},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H066","WaterLevel": 138.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H077","WaterLevel": 740.49},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1550H014","WaterLevel": 26.75},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1670H004","WaterLevel": 2.98},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H019","WaterLevel": 109.97},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H012","WaterLevel": 0.7},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H061","WaterLevel": 266.23},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H072","WaterLevel": 248.86},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H039","WaterLevel": 38.99},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H012","WaterLevel": 0.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H025","WaterLevel": 261.61},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H009","WaterLevel": 0.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H057","WaterLevel": 43.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H068","WaterLevel": 10.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H037","WaterLevel": 32.01},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H015","WaterLevel": 0.05},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H018","WaterLevel": 124.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H036","WaterLevel": 65.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H009","WaterLevel": 4.85},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H043","WaterLevel": 23.04},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H043","WaterLevel": 79.32},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H033","WaterLevel": 23.4},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H010","WaterLevel": 0.19},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H030","WaterLevel": 1.57},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H032","WaterLevel": 0.13},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H013","WaterLevel": 5.62},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1680H005","WaterLevel": 0.11},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H026","WaterLevel": 106.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1350H031","WaterLevel": -0.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H040","WaterLevel": 1.76},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H018","WaterLevel": 10.01},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H027","WaterLevel": 26.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM", ...

# %%
import json

json.loads(r1.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.75},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.98},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': 109.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H012',
#    'WaterLevel': 0.7},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.23},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.86},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 38.99},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': 0.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.61},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': 43.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 32.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': 0.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': 124.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.85},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': 23.04},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.32},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.4},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': 0.19},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.57},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 0.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.62},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H026',
#    'WaterLevel': 106.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.01},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.45},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.54},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.03},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': 175.97},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.27},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.07},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 13.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H027',
#    'WaterLevel': 145.89},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': 752.39},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 0.16},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.06},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': 0.59},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': 1068.94},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': 12.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.46},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.66},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.67},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': 78.22},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': 21.23},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.7},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': 470.82},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.6},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.35},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': 220.79},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': 317.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': 19.39},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.41},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': 97.9},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': 15.74},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': 346.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 622.43},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.68},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': 50.08},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': 704.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': 191.55},
#   {'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': 49.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': 58.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.19},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': 169.81},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': -1.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.38},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': 12.12},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': 263.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.09},
#   {'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': 310.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
